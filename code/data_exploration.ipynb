# %%
import pandas as pd

combined_raw_data = pd.read_csv('../data/raw/combined_raw_data.csv')
combined_raw_data.head()
# Out:
#                   Unnamed: 0                AAPL              AAPL.1  \
# 0                        NaN                Open                High
# 1  2013-01-02 00:00:00-05:00  16.726068314487094   16.76170582486638
# 2  2013-01-03 00:00:00-05:00   16.54666598301802  16.600726265962198
# 3  2013-01-04 00:00:00-05:00  16.217164068387454   16.26729848146638
# 4  2013-01-07 00:00:00-05:00  15.765068649115538  15.985537407314801
#
#                AAPL.2              AAPL.3     AAPL.4                ABBV  \
# 0                 Low               Close     Volume                Open
# 1  16.357915654650395  16.581403732299805  560518000  20.443969182924974
# 2  16.338881397575303  16.372102737426758  352965200  20.490810665292805
# 3  15.880721720706754  15.916057586669922  594333600   20.26834354533764
# 4    15.5597000709912    15.8224515914917  484156400  19.993178739921877
#
#                ABBV.1              ABBV.2              ABBV.3  ...  \
# ...

# %%
combined_raw_data.tail(10)
# Out:
#                      Unnamed: 0                AAPL              AAPL.1  \
# 3300  2026-02-13 00:00:00-05:00   261.7688319830923   261.9886306947134
# 3301  2026-02-17 00:00:00-05:00   257.8124646511843   266.0449008431299
# 3302  2026-02-18 00:00:00-05:00  263.35737977838915  266.57441720150126
# 3303  2026-02-19 00:00:00-05:00  262.35827847824623   264.2365527856389
# 3304  2026-02-20 00:00:00-05:00  258.73163460792017   264.5063132392292
# 3305  2026-02-23 00:00:00-05:00  263.24744081710827   269.1819753311392
# 3306  2026-02-24 00:00:00-05:00  267.61343657617186   274.6369951599546
# 3307  2026-02-25 00:00:00-05:00   271.5298429675081   274.6869380517792
# 3308  2026-02-26 00:00:00-05:00   274.6969199809464   275.8558253670768
# 3309  2026-02-27 00:00:00-05:00   272.5588900215503   272.5588900215503
#
#                   AAPL.2              AAPL.3    AAPL.4                ABBV  \
# 3300  255.21485759663088   255.5445556640625  56290700  226.54058542130937
# ...

# %%
combined_raw_data.info()

# %%
APPL = pd.read_csv('../data/raw/by_ticker/AAPL.csv')
APPL.head()
# Out:
#                         Date      Open      High       Low     Close  \
# 0  2010-03-01 00:00:00-05:00  6.159214  6.271472  6.150234  6.256206
# 1  2010-03-02 00:00:00-05:00  6.284344  6.311286  6.218785  6.252014
# 2  2010-03-03 00:00:00-05:00  6.254709  6.282549  6.224774  6.266383
# 3  2010-03-04 00:00:00-05:00  6.264886  6.313980  6.245428  6.307693
# 4  2010-03-05 00:00:00-05:00  6.434321  6.576814  6.425041  6.554362
#
#       Volume
# 0  550093600
# 1  566546400
# 2  372052800
# 3  366041200
# 4  899620400

# %%
period_0 = pd.read_csv('../data/processed/period_0_normalized.csv')
period_0.head(10)
# Out:
#             Unnamed: 0      AAPL      ABBV       AMD      AVGO       BAC  \
# 0  2013-01-03 05:00:00 -0.800705 -0.510449 -0.485160  0.149488 -0.376048
# 1  2013-01-04 05:00:00 -1.744336 -0.759073  1.190435 -0.385458  0.761204
# 2  2013-01-07 05:00:00 -0.387719  0.070085  0.919171 -0.344759 -0.116072
# 3  2013-01-08 05:00:00  0.133411 -1.281487 -0.002382 -0.403334 -0.581404
# 4  2013-01-09 05:00:00 -0.985794  0.271766 -0.459653  0.914688 -2.934080
# 5  2013-01-10 05:00:00  0.718017  0.121390 -0.117789  0.893206  1.861094
# 6  2013-01-11 05:00:00 -0.403004  0.372567  0.570296  1.019888 -0.809807
# 7  2013-01-14 05:00:00 -2.233103  0.353009 -0.344687  0.216750 -0.874272
# 8  2013-01-15 05:00:00 -1.975479  0.790719  0.453170 -1.028989  0.418585
# 9  2013-01-16 05:00:00  2.438756  1.462991  0.446421  0.836183  1.212041
#
#           C     CMCSA       COP       CVX  ...      MSFT      NFLX      NVDA  \
# 0  0.209089 -0.945146 -0.026320 -0.306868  ... -0.934323  1.433436 -0.032725
# ...

# %%
period_0.tail(10)
# Out:
#               Unnamed: 0      AAPL      ABBV       AMD      AVGO       BAC  \
# 817  2016-04-04 04:00:00  0.590678  1.681822 -0.002382 -0.613549 -0.242933
# 818  2016-04-05 04:00:00 -0.749498 -0.684114 -0.761118 -0.379083 -1.503098
# 819  2016-04-06 04:00:00  0.602623  1.237730  0.433505  0.647649  0.362432
# 820  2016-04-07 04:00:00 -1.368085 -0.600898 -1.784875 -0.844936 -2.012150
# 821  2016-04-08 04:00:00  0.037352 -0.836825  1.123905  0.258526  0.131550
# 822  2016-04-11 04:00:00  0.171055 -0.015389  0.217936 -0.248803  0.419394
# 823  2016-04-12 04:00:00  0.755738  1.276157  0.541504 -0.142911  1.407753
# 824  2016-04-13 04:00:00  0.843279 -0.291221 -0.110381  1.091289  2.375438
# 825  2016-04-14 04:00:00  0.002781  0.164807 -0.880520 -0.280167  1.544283
# 826  2016-04-15 04:00:00 -1.260331  0.173514 -0.225953 -1.062670 -0.631736
#
#             C     CMCSA       COP       CVX  ...      MSFT      NFLX  \
# 817 -0.625860 -0.264763 -0.946848 -0.636300  ... -0.225070 -0.481206
# ...

# %%
period_1 = pd.read_csv('../data/processed/period_1_normalized.csv')
period_1.head(10)
# Out:
#             Unnamed: 0      AAPL      ABBV        AMD      AVGO       BAC  \
# 0  2016-04-18 04:00:00 -1.497016  0.336809   0.461374  0.092617  0.721274
# 1  2016-04-19 04:00:00 -0.407128  0.258667  -1.343966 -1.738417  1.210865
# 2  2016-04-20 04:00:00  0.080064  0.276263   0.658858  0.713413  2.067081
# 3  2016-04-21 04:00:00 -0.775163  0.817645  -0.808014 -0.711548 -0.198289
# 4  2016-04-22 04:00:00 -0.236854  0.029038  10.182105 -0.411799  0.847038
# 5  2016-04-25 04:00:00 -0.431987 -0.437987  -3.620550 -0.489860 -0.718458
# 6  2016-04-26 04:00:00 -0.516419 -0.055060   1.366297  0.545647  0.498109
# 7  2016-04-27 04:00:00 -4.326026 -0.233748   0.387395  0.224716 -0.370548
# 8  2016-04-28 04:00:00 -2.107112  0.451477  -0.871975 -1.317868 -1.074634
# 9  2016-04-29 04:00:00 -0.819712 -0.204685  -0.483272 -0.867626 -1.090413
#
#           C     CMCSA       COP       CVX  ...      MSFT      NFLX      NVDA  \
# ...
