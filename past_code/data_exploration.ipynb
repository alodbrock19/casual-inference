# %%
import pandas as pd

combined_raw_data = pd.read_csv('../data/raw/close_prices.csv')
combined_raw_data.head()
# Out:
#          Date      GOOGL       META      NFLX        DIS      CMCSA  \
# 0  2013-01-02  17.940264  27.756256  1.314429  45.040714  13.100780
# 1  2013-01-03  17.950686  27.528259  1.379857  45.137672  12.954531
# 2  2013-01-04  18.305403  28.509638  1.371143  46.001465  12.947733
# 3  2013-01-07  18.225529  29.163897  1.417143  44.926121  12.889916
# 4  2013-01-08  18.189564  28.807028  1.388000  44.741032  12.978337
#
#         TMUS        XOM        CVX        COP  ...      NVDA      AVGO   AMD  \
# 0  15.371295  51.692493  63.153805  37.723972  ...  0.293077  2.359186  2.53
# 1  15.260368  51.599289  62.884914  37.698490  ...  0.293307  2.371511  2.49
# 2  15.418836  51.838173  63.216763  38.119003  ...  0.302984  2.356287  2.59
# 3  15.149442  51.237999  62.787666  37.698490  ...  0.294229  2.343236  2.67
# 4  14.784968  51.558479  62.507313  37.188805  ...  0.287778  2.327286  2.67
#
#         ORCL        UNH        JNJ        LLY       ABBV        PFE        MRK
# ...

# %%
combined_raw_data.tail(10)
# Out:
#             Date       GOOGL        META       NFLX         DIS      CMCSA  \
# 3299  2026-02-13  305.322571  638.630798  76.870003  104.648132  30.787640
# 3300  2026-02-17  301.627350  638.151672  77.000000  104.638214  30.768135
# 3301  2026-02-18  302.935669  642.074646  77.989998  106.285591  30.816898
# 3302  2026-02-19  302.456299  643.631897  77.000000  105.193954  30.602346
# 3303  2026-02-20  314.570526  654.492554  78.669998  104.777153  30.563339
# 3304  2026-02-23  311.085052  636.115356  76.019997  103.616051  30.846153
# 3305  2026-02-24  310.495850  638.161682  78.040001  105.243576  30.826649
# 3306  2026-02-25  312.493225  652.526001  82.699997  104.251183  30.026972
# 3307  2026-02-26  306.980438  655.840149  84.589996  104.747383  30.085484
# 3308  2026-02-27  311.354736  647.025818  96.239998  105.233650  30.192755
#
#             TMUS         XOM         CVX         COP  ...        NVDA  \
# 3299  217.270737  147.449188  180.308533  109.753883  ...  182.587311
# ...

# %%
combined_raw_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3309 entries, 0 to 3308
# Data columns (total 31 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    3309 non-null   object
#  1   GOOGL   3309 non-null   float64
#  2   META    3309 non-null   float64
#  3   NFLX    3309 non-null   float64
#  4   DIS     3309 non-null   float64
#  5   CMCSA   3309 non-null   float64
#  6   TMUS    3309 non-null   float64
#  7   XOM     3309 non-null   float64
#  8   CVX     3309 non-null   float64
#  9   COP     3309 non-null   float64
#  10  SLB     3309 non-null   float64
#  11  EOG     3309 non-null   float64
#  12  MPC     3309 non-null   float64
#  13  JPM     3309 non-null   float64
#  14  BAC     3309 non-null   float64
#  15  MS      3309 non-null   float64
#  16  GS      3309 non-null   float64
#  17  C       3309 non-null   float64
#  18  WFC     3309 non-null   float64
#  19  AAPL    3309 non-null   float64
# ...

# %%
APPL = pd.read_csv('../data/raw/by_ticker/AAPL.csv')
APPL.head()

# %%
period_0 = pd.read_csv('../data/processed/period_0_normalized.csv')
period_0.head(10)

# %%
period_0.tail(10)

# %%
period_1 = pd.read_csv('../data/processed/period_1_normalized.csv')
period_1.head(10)

# %%
import pandas as pd
granger = pd.read_csv('../data/processed/granger_stock_pairs_pooled_results.csv')
granger.head(10)

# %%
import pandas as pd
granger = pd.read_csv('/home/alrodriguezg/U/s6/causal_inference/project/casual-inference/data/processed/adjacency_period0_consensus.csv')
granger.head(10)

# %%
from visualize_granger_graph import plot_granger_graph

plot_granger_graph(
    '/home/alrodriguezg/U/s6/causal_inference/project/casual-inference/data/processed/adjacency_te_log_return_period3_K4.csv',
    title='Period 0 - Consensus Graph'
)
# Out:
# (<networkx.classes.digraph.DiGraph at 0x74cdc822ceb0>,
#  <Figure size 1000x1000 with 1 Axes>,
#  <Axes: title={'center': 'Period 0 - Consensus Graph\n30 nodes, 16 edges (10 isolated)'}>)

# %%
from visualize_granger_graph import plot_granger_graph

plot_granger_graph(
    '/home/alrodriguezg/U/s6/causal_inference/project/casual-inference/data/processed/adjacency_digauss_log_return_period0_consensus.csv',
    title='Period 0 - Consensus Graph'
)
# Out:
# (<networkx.classes.digraph.DiGraph at 0x74cdc819d960>,
#  <Figure size 1000x1000 with 1 Axes>,
#  <Axes: title={'center': 'Period 0 - Consensus Graph\n30 nodes, 67 edges (2 isolated)'}>)
